# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from multiprocessing import Pool, cpu_count
import itertools
# %matplotlib inline

rootpath = '/media/share/data/kaggle/ieee-camera/'

# %%
## MultiGPU Code
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
set_session(tf.Session(config=config))


import keras.utils.training_utils
from keras.utils import multi_gpu_model
gdev = keras.utils.training_utils._get_available_devices()
print(gdev)
gdev_count = 0
for i, n in enumerate(gdev):
    if 'device:GPU' in n:
        gdev_count+=1
if gdev_count > 0:
    print('Found {} GPUs, will attempt to use all of them.'.format(gdev_count))
else:
    gdev_count=1
    print('Did not find any GPUs, this will be SLOW!')

# %% [markdown]
# # Preprocess

# %%
# creat a flickr_val
urlpath = os.path.join(rootpath, 'val_images')
subdir = os.listdir(urlpath)
# subdir.remove('good_jpgs')
temp_df = []
for idx in subdir:
    temp_df.append((idx, pd.read_csv(os.path.join(urlpath, idx) + '/' + os.listdir(os.path.join(urlpath, idx))[0], header=None)))

df_flickr = pd.DataFrame(temp_df, columns=['class', 'fname'])

df_flickr['class'] = ['Motorola-X', 'iPhone-6', 'Motorola-Nexus-6', 'LG-Nexus-5x', 'Motorola-Droid-Maxx', 'HTC-1-M7', 'iPhone-4s', 'Sony-NEX-7', 'Samsung-Galaxy-S4', 'Samsung-Galaxy-Note3']

df = pd.DataFrame([])
for idx in range(len(df_flickr['class'])):
    target = df_flickr['fname'][idx]
    target.columns = ['fname']
    target = pd.DataFrame(target)
    n_class = pd.DataFrame(np.repeat(df_flickr['class'][idx], len(target)))
    df_temp = pd.concat([n_class.reset_index(drop=True), target.reset_index(drop=True)], 1)
    df = pd.concat([df, df_temp], 0)
    
df.columns = ['class', 'fname']
df.to_csv('/media/share/data/kaggle/ieee-camera/val_flickr.csv', index=None)

# %%
# creat a flickr_train
urlpath = os.path.join(rootpath, 'flickr_images')
subdir = os.listdir(urlpath)
subdir.remove('good_jpgs')
temp_df = []
for idx in subdir:
    temp_df.append((idx, pd.read_csv(os.path.join(urlpath, idx) + '/urls_final', header=None)))

df_flickr = pd.DataFrame(temp_df, columns=['class', 'fname'])

df_flickr['class'] = ['Motorola-X', 'iPhone-6', 'Motorola-Nexus-6', 'LG-Nexus-5x', 'Motorola-Droid-Maxx', 'HTC-1-M7', 'iPhone-4s', 'Sony-NEX-7', 'Samsung-Galaxy-S4', 'Samsung-Galaxy-Note3']

df = pd.DataFrame([])
for idx in range(len(df_flickr['class'])):
    target = df_flickr['fname'][idx]
    target.columns = ['fname']
    target = pd.DataFrame(target)
    n_class = pd.DataFrame(np.repeat(df_flickr['class'][idx], len(target)))
    df_temp = pd.concat([n_class.reset_index(drop=True), target.reset_index(drop=True)], 1)
    df = pd.concat([df, df_temp], 0)
    
df.columns = ['class', 'fname']
df.to_csv('/media/share/data/kaggle/ieee-camera/train_flickr.csv', index=None)

# %%
train_df = pd.read_csv('/media/share/data/kaggle/ieee-camera/train_flickr.csv')
train_df.head()
# Out:
#         class                                              fname
# 0  Motorola-X  https://c1.staticflickr.com/9/8340/28442295042...
# 1  Motorola-X  https://c2.staticflickr.com/8/7645/27350291351...
# 2  Motorola-X  https://c2.staticflickr.com/8/7533/27387770246...
# 3  Motorola-X  https://c2.staticflickr.com/2/1555/24073174483...
# 4  Motorola-X  https://c2.staticflickr.com/2/1636/24073199913...

# %%
val_df = pd.read_csv('/media/share/data/kaggle/ieee-camera/val_flickr.csv')
val_df.head()
# Out:
#         class                                              fname
# 0  Motorola-X  https://3.img-dpreview.com/files/p/sample_gall...
# 1  Motorola-X  https://3.img-dpreview.com/files/p/sample_gall...
# 2  Motorola-X  https://2.img-dpreview.com/files/p/sample_gall...
# 3  Motorola-X  https://2.img-dpreview.com/files/p/sample_gall...
# 4  Motorola-X  https://1.img-dpreview.com/files/p/sample_gall...

# %%
def mp_idx(idx):
    # multiple processing with cpus
    from skimage import io

    img_file = []
    label = []
    crop_size = 512
    
    if idx == 'train_idx':
        df = train_df
    else:
        df = val_df
        
    print(df['fname'][idx])
    img = io.imread(df['fname'][idx])
    if len(img.shape) == 3:
        h1, w1, _ = img.shape

        for i in range(4):
            hr = np.random.randint(0, h1-crop_size)
            wr = np.random.randint(0, w1-crop_size)
            tem_img = img[hr:hr+crop_size, wr:wr+crop_size, :]
            img_file.append(tem_img)
            label.append(df['class'][idx])
            
    return img_file, label


def image_crop(indexlist):
    from keras.applications.densenet import preprocess_input
    
    with Pool(cpu_count()) as pool:
        img_file, label = zip(*pool.map(mp_idx, indexlist))
    
    img_file = list(itertools.chain(*img_file))
    label = list(itertools.chain(*label))
        
    from sklearn.preprocessing import LabelEncoder
    from keras.utils import to_categorical
    le = LabelEncoder().fit(n_class)
    labels = to_categorical(le.transform(label), num_classes=len(n_class))
    
    img_file = preprocess_input(np.array(img_file))
    return img_file, labels

# %%
def image_crop(indexlist):
    from keras.applications.densenet import preprocess_input
    from skimage import io

    img_file = []
    label = []
    crop_size = 512
    
    if indexlist == 'train_idx':
        df = train_df
    else:
        df = val_df
        
    for idx in range(len(df['fname'])):
        print(df['fname'][idx])
        img = io.imread(df['fname'][idx])
        
        if len(img.shape) == 3:
            h1, w1, _ = img.shape

            for i in range(4):
                hr = np.random.randint(0, h1-crop_size)
                wr = np.random.randint(0, w1-crop_size)
                tem_img = img[hr:hr+crop_size, wr:wr+crop_size, :]
                img_file.append(tem_img)
                label.append(df['class'][idx])

        
    from sklearn.preprocessing import LabelEncoder
    from keras.utils import to_categorical
    le = LabelEncoder().fit(n_class)
    labels = to_categorical(le.transform(label), num_classes=len(n_class))
    
    img_file = preprocess_input(np.array(img_file))
    return img_file, labels

# %%
# from sklearn.model_selection import StratifiedKFold
# n_fold = 5
# skf = StratifiedKFold(n_fold, shuffle=True, random_state=np.random)
# for train_idx, val_idx in skf.split(train_df['fname'], train_df['class']):
#     break

# %%
from sklearn.utils import class_weight

class_weight = class_weight.compute_class_weight('balanced', np.unique(train_df['class']), train_df['class'])

# %% [markdown]
# # CNN model

# %% [markdown]
# ## DenseNet-201

# %%
import keras.backend as K
from keras.applications import densenet
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.layers import Dense, Flatten, GlobalAveragePooling2D
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.optimizers import Adam
import datetime

K.clear_session()

base_model = densenet.DenseNet201(include_top=False, weights='imagenet', input_shape=(512, 512, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dense(10, activation='softmax')(x)

smodel = Model(inputs=base_model.input, outputs=x)
smodel.summary()

# Multimodel
if gdev_count > 1:
    model = multi_gpu_model(smodel, gdev_count)
    model.summary()
else:
    model = smodel
    
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Trainning

# %%
import random
train_idx = np.arange(len(train_df))
random.shuffle(train_idx)
val_idx = np.arange(len(val_df))
random.shuffle(val_idx)

X_train, y_train = image_crop(train_idx)
X_val, y_val = image_crop(val_idx)
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if __name__ == '__main__':
# https://3.img-dpreview.com/files/p/sample_galleries/5521548249/0593558516.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5521548249/3675963866.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5521548249/0312125868.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5521548249/9025633101.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5521548249/4163184428.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5521548249/3813083218.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5521548249/3928181352.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5521548249/4122247355.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5521548249/5752873473.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5521548249/2725668255.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5521548249/5123862399.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5521548249/6078095745.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5521548249/7456611874.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5521548249/6835896390.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5521548249/8375110767.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5521548249/7197147087.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5521548249/4165352334.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5521548249/5102478605.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5521548249/3173676810.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5521548249/0123323558.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5521548249/5167650138.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5521548249/8031841214.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5521548249/9631664728.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5521548249/4094275209.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5521548249/1030911813.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5521548249/0384712209.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5521548249/7776264810.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5521548249/6615599722.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5521548249/3821696898.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5521548249/0262835376.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/2985242251/8068224892.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/2985242251/6966269410.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/2985242251/8497758798.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/2985242251/0408919859.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/2985242251/0422107871.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/2985242251/9178123021.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/2985242251/3629786676.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/2985242251/7153866522.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/2985242251/3004974300.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/2985242251/2847233334.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/2985242251/3101468981.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/2985242251/4267333809.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/2985242251/0507347470.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/2985242251/2258811795.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/2985242251/3922502823.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/2985242251/0374521407.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/2985242251/7468753403.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/2985242251/1885521790.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/2985242251/3330574676.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/2985242251/9737338153.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/2985242251/8245349000.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/2985242251/8582958091.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/2985242251/1664467551.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/2985242251/9204605187.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/2985242251/5254499992.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/2985242251/5908050153.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/2985242251/0668773348.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/2985242251/4717984730.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/2985242251/5065137991.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/2985242251/1516392540.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/3316615550/8946551004.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/3316615550/0335259263.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/3316615550/9785219947.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/3316615550/2827955374.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/3316615550/5017875755.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/3316615550/6837238704.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/3316615550/4255007605.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/3316615550/3358731032.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/3316615550/0171677908.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/3316615550/6510260041.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/3316615550/8871852579.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/3316615550/8822143348.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/3316615550/9619910060.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/3316615550/5961042987.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/3316615550/2765926019.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/3316615550/5210431922.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/3316615550/3363130612.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/3316615550/5086184977.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/3316615550/3270769828.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/3316615550/2275174937.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/3316615550/1989371737.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/3316615550/8094164721.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/3316615550/3273116215.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/3316615550/2954829835.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/3316615550/0287630386.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/3316615550/7760695230.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/3316615550/0799676260.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/3316615550/6241809555.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/799/0/S3667990/slug/l/img-20151017-010650-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/799/1/S3667991/slug/l/img-20151017-095712-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/799/2/S3667992/slug/l/img-20151017-095739-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/799/3/S3667993/slug/l/img-20151017-100042-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/799/4/S3667994/slug/l/img-20151017-100752-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/799/5/S3667995/slug/l/img-20151017-100807-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/799/6/S3667996/slug/l/img-20151017-121342-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/799/7/S3667997/slug/l/img-20151017-121610-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/799/8/S3667998/slug/l/img-20151017-121627-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/799/9/S3667999/slug/l/img-20151017-121712-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/800/0/S3668000/slug/l/img-20151017-121717-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/800/1/S3668001/slug/l/img-20151017-122318-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/800/2/S3668002/slug/l/img-20151017-122628-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/800/3/S3668003/slug/l/img-20151017-122717-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/800/4/S3668004/slug/l/img-20151017-122730-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/800/5/S3668005/slug/l/img-20151017-122828-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/800/6/S3668006/slug/l/img-20151017-122846-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/800/7/S3668007/slug/l/img-20151017-122907-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/800/8/S3668008/slug/l/img-20151017-122922-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/800/9/S3668009/slug/l/img-20151017-123434-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/801/0/S3668010/slug/l/img-20151017-124105-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/801/1/S3668011/slug/l/img-20151017-125059-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/801/2/S3668012/slug/l/img-20151017-133233-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/801/3/S3668013/slug/l/img-20151017-133239-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/801/4/S3668014/slug/l/img-20151017-133339-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/801/5/S3668015/slug/l/img-20151017-133349-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/801/6/S3668016/slug/l/img-20151017-133356-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/801/7/S3668017/slug/l/img-20151017-154836-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/801/8/S3668018/slug/l/img-20151017-155104-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/801/9/S3668019/slug/l/img-20151017-155107-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/802/0/S3668020/slug/l/img-20151017-194214-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/802/1/S3668021/slug/l/img-20151017-194327-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/802/2/S3668022/slug/l/img-20151017-194446-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/802/3/S3668023/slug/l/img-20151017-194455-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/802/4/S3668024/slug/l/img-20151017-194504-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/802/5/S3668025/slug/l/img-20151017-200013-1.jpg
# https://s.blogcdn.com/slideshows/images/slides/366/802/6/S3668026/slug/l/img-20151017-203107-1.jpg
# https://i-cdn.phonearena.com/images/reviews/139205-image/Motorola-DROID-MAXX-Sample-Images.jpg
# https://i-cdn.phonearena.com/images/reviews/139206-image/Motorola-DROID-MAXX-Sample-Images.jpg
# https://i-cdn.phonearena.com/images/reviews/139207-image/Motorola-DROID-MAXX-Sample-Images.jpg
# https://i-cdn.phonearena.com/images/reviews/139208-image/Motorola-DROID-MAXX-Sample-Images.jpg
# https://i-cdn.phonearena.com/images/reviews/139209-image/Motorola-DROID-MAXX-Sample-Images.jpg
# https://i-cdn.phonearena.com/images/reviews/139210-image/Motorola-DROID-MAXX-Sample-Images.jpg
# https://i-cdn.phonearena.com/images/reviews/139211-image/Motorola-DROID-MAXX-Sample-Images.jpg
# https://i-cdn.phonearena.com/images/reviews/139212-image/Motorola-DROID-MAXX-Sample-Images.jpg
# https://i-cdn.phonearena.com/images/reviews/139213-image/Motorola-DROID-MAXX-Sample-Images.jpg
# https://i-cdn.phonearena.com/images/reviews/139214-image/Motorola-DROID-MAXX-Sample-Images.jpg
# https://i-cdn.phonearena.com/images/reviews/139215-image/Strong-light.jpg
# https://i-cdn.phonearena.com/images/reviews/139216-image/Medium-nbsplight.jpg
# https://i-cdn.phonearena.com/images/reviews/139217-image/Low-light.jpg
# https://i-cdn.phonearena.com/images/reviews/139218-image/Darkness.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/3769653152.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/4658019505.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/4279611148/3581003618.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/4279611148/1949349001.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/5522037591.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/9896046582.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/5819127427.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/4279611148/5315806079.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/0758676544.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/9136120615.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/5772588192.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/0092477189.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/4279611148/3868594816.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/4279611148/1739791301.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/3892818962.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/7080720028.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/4279611148/0277695896.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/1867981988.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/4279611148/6116267652.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/4279611148/7500729361.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/4279611148/0546697912.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/6394223874.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/4279611148/4924177177.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/5826648767.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/4279611148/4210683880.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/8949800199.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/1996279770.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/4279611148/7298334898.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/0338025145.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/4279611148/7243326986.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/4279611148/2189320696.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/1927060896.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/6073763816.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/4279611148/2702695349.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/0032376087.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/3273754334.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/4209010853.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/9445874168.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/7745599459.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/7916485576.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/4279611148/7957735563.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/3478662027.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/4279611148/3084771314.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/4279611148/0538100148.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/4279611148/4887199261.jpg
# https://images.anandtech.com/galleries/1495/1-4S.jpg
# https://images.anandtech.com/galleries/1495/2-4S.jpg
# https://images.anandtech.com/galleries/1495/3-4S.jpg
# https://images.anandtech.com/galleries/1495/4-4S.jpg
# https://images.anandtech.com/galleries/1495/5-4S.jpg
# https://images.anandtech.com/galleries/1495/6-4S.jpg
# https://images.anandtech.com/galleries/1495/7-4S.jpg
# https://images.anandtech.com/galleries/1495/8-4S.jpg
# https://images.anandtech.com/galleries/1495/9-4S.jpg
# https://images.anandtech.com/galleries/1495/10-4S.jpg
# https://images.anandtech.com/galleries/1495/11-4S.jpg
# https://images.anandtech.com/galleries/1495/12-4S.jpg
# https://images.anandtech.com/galleries/1495/13-4S.jpg
# https://images.anandtech.com/galleries/1495/14-4S.jpg
# https://images.anandtech.com/galleries/1495/15-4S-HDR.jpg
# https://images.anandtech.com/galleries/1495/16-4S-HDR.jpg
# https://images.anandtech.com/galleries/1495/17-4S-HDR.jpg
# https://images.anandtech.com/galleries/1495/18-4S-HDR.jpg
# https://images.anandtech.com/galleries/1495/19-4S-HDR.jpg
# https://images.anandtech.com/galleries/1495/20-4S-LL.jpg
# https://images.anandtech.com/galleries/1495/21-4S-LL.jpg
# https://images.anandtech.com/galleries/1495/22-4S-LL.jpg
# https://images.anandtech.com/galleries/1495/23-4S-LL.jpg
# https://images.anandtech.com/galleries/1495/24-4S-LL.jpg
# https://images.anandtech.com/galleries/1495/25-4S.jpg
# https://images.anandtech.com/galleries/1495/26-4S.jpg
# https://images.anandtech.com/galleries/1495/27-4S.jpg
# https://images.anandtech.com/galleries/1495/28-4S.jpg
# https://images.anandtech.com/galleries/1495/29-4S.jpg
# https://images.anandtech.com/galleries/1495/30-4S.jpg
# https://images.anandtech.com/galleries/1495/iPhone%204S.JPG
# https://2.img-dpreview.com/files/p/sample_galleries/5563556166/3958537665.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5563556166/7040276174.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/7899519935.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5563556166/7421691743.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/8671492354.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5563556166/9140533128.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5563556166/7829672122.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/5017405834.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5563556166/1199473756.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/1477771810.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/6827651321.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5563556166/6464706577.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5563556166/8555581173.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/3035665678.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/2598678952.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5563556166/3539323570.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5563556166/8494957433.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5563556166/0331125303.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5563556166/3781333292.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5563556166/9340675409.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5563556166/9337740327.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5563556166/7223369608.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5563556166/9901777145.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5563556166/0803131957.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/8724911423.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5563556166/6856121001.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/2662401761.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5563556166/9031862365.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5563556166/0449314722.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5563556166/7700630230.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/1414443578.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/0142327815.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5563556166/9444427802.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5563556166/7542367589.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5563556166/5878318176.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5563556166/4190536851.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5563556166/8682603386.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/5966315574.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/9209582011.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5563556166/4763911829.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/5563556166/9545561438.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/7471068583.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/0743195378.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/5563556166/8550841230.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/1480675260.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5563556166/9853771027.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/5563556166/4569488900.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/5563556166/8377995928.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/7804196400/7037445193.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/7804196400/0001050095.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/7804196400/5317083150.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/7804196400/7511538539.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/7804196400/2718393870.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/7804196400/7774008813.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/7804196400/8358164996.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/7804196400/9415703650.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/7804196400/2739347212.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/7804196400/4211528521.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/7804196400/1952286160.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/7804196400/5842423075.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/7804196400/1199999617.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/7804196400/6721682787.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/7804196400/2188791889.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/7804196400/7838023432.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/7804196400/4788957166.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/7804196400/4586516778.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/7804196400/1455529825.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/7804196400/0794726526.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/7804196400/7759556599.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/7804196400/3036463076.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/7804196400/5172746426.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/7804196400/5123094934.jpg
# https://2.img-dpreview.com/files/p/sample_galleries/7804196400/2343808035.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/7804196400/7375413841.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/7804196400/1357827618.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/7804196400/1212783534.jpg
# https://3.img-dpreview.com/files/p/sample_galleries/7804196400/7780308031.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/7804196400/9437183397.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/7804196400/5065559966.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/7804196400/5783006031.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/7804196400/9032483720.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/7804196400/1466167851.jpg
# https://4.img-dpreview.com/files/p/sample_galleries/7804196400/7793186160.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/7804196400/0521980202.jpg
# https://1.img-dpreview.com/files/p/sample_galleries/7804196400/9515542466.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-b010536d8122> in <module>()
#       5 random.shuffle(val_idx)
#       6
# ----> 7 X_train, y_train = image_crop(train_idx)
#       8 X_val, y_val = image_crop(val_idx)
#
# <ipython-input-7-d760efae26a3> in image_crop(indexlist)
#      14     for idx in range(len(df['fname'])):
#      15         print(df['fname'][idx])
# ---> 16         img = io.imread(df['fname'][idx])
#      17
#      18         if len(img.shape) == 3:
#
# /opt/conda/lib/python3.6/site-packages/skimage/io/_io.py in imread(fname, as_grey, plugin, flatten, **plugin_args)
#      58             plugin = 'tifffile'
#      59
# ---> 60     with file_or_url_context(fname) as fname:
#      61         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      62
#
# /opt/conda/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /opt/conda/lib/python3.6/site-packages/skimage/io/util.py in file_or_url_context(resource_name)
#      28             with tempfile.NamedTemporaryFile(delete=False, suffix=ext) as f:
#      29                 u = urlopen(resource_name)
# ---> 30                 f.write(u.read())
#      31             # f must be closed before yielding
#      32             yield f.name
#
# /opt/conda/lib/python3.6/http/client.py in read(self, amt)
#     460             else:
#     461                 try:
# --> 462                     s = self._safe_read(self.length)
#     463                 except IncompleteRead:
#     464                     self._close_conn()
#
# /opt/conda/lib/python3.6/http/client.py in _safe_read(self, amt)
#     610         s = []
#     611         while amt > 0:
# --> 612             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     613             if not chunk:
#     614                 raise IncompleteRead(b''.join(s), amt)
#
# /opt/conda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /opt/conda/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# /opt/conda/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /opt/conda/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
train_gen = ImageDataGenerator(horizontal_flip=True, 
                               vertical_flip=True)

# %%
model.load_weights('ieeev3-irv2-36-0.0800.hdf5')

model_checkpoint = ModelCheckpoint('ieeev3-irv2cw-{epoch:02d}-{val_loss:.4f}.hdf5',
                                   monitor='val_loss', save_best_only=True, save_weights_only=True)

model_earlystop = EarlyStopping(patience=32, monitor='val_loss')

batch_size = 64 * gdev_count

train_history = model.fit_generator(train_gen.flow(X_train, y_train, batch_size), 
                                    epochs=2**8, steps_per_epoch=2**11, 
                                    validation_data=train_gen.flow(X_val, y_val, batch_size), 
                                    validation_steps=len(),
                                    verbose=2, callbacks=[model_checkpoint, model_earlystop])

# %% [markdown]
# # Prediction

# %%
testpath = os.path.join(rootpath, 'test')
submitpath = '/media/share/jiaxin_cmu/kaggle/ieee_camera/submition/'

submit_df = pd.read_csv(rootpath + '/sample_submission.csv')
    
model.load_weights('ieeev3-irv2-39-0.0715.hdf5')

img_file = []
for idx in submit_df['fname']:
    img = plt.imread(testpath + '/' + idx)

prediction = model.predict(np.array(img_file))

# %%
# prediction = [0]

# for ii in range(4):
#     prediction = np.add(model.predict(np.array(img_file[ii*len(submit_df):(ii+1)*len(submit_df)])), prediction)

# %%
# def mp_predic():
#     img_file = []
#     for idx in submit_df['fname']:
#         img = plt.imread(testpath + '/' + idx)

#         hr = np.random.randint(0, 256)
#         wr = np.random.randint(0, 256)
#         tem_img = img[hr:hr+256, wr:wr+256, :]
#         img_file.append(tem_img / 255.)
        
#     predPoolion = model.predict(np.array(img_file))
        
#     return prediction

# with Pool(cpu_count()) as pool:
#     prediction = pool.map(mp_idx, range(128))
    
# prediction = np.add(model.predict(np.array(img_file)), prediction)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder().fit(n_class)
predict_class = le.inverse_transform(prediction.argmax(axis=-1))

# %%
submit_df['camera'] = predict_class
submit_df.to_csv(submitpath + '/' + 'submit07.csv', index=False)

# %%
urlpath = '/media/share/data/kaggle/ieee-camera/flickr_images/iphone_4s/'
urls_final = pd.read_csv(urlpath + 'urls_final', header=None)
urls_final.columns = ['url']

# %%
from skimage import io
image = io.imread(urls_final['url'].iloc[1])

# %%
urls_final['url'].iloc[1]

# %%
plt.imshow(image)
